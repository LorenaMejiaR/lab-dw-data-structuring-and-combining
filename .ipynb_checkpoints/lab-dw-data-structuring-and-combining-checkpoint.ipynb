# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
# Your code goes here
import pandas as pd
import seaborn as sns
customer_data= pd.read_csv("customer_data_clean.csv")
customer_data2= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
customer_data3= pd. read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")

# %%
display(customer_data)
# Out:
#     customer       state gender             education  \
# 0    QZ44356     Arizona      F              Bachelor
# 1    WW63253  California      M              Bachelor
# 2    GA49547  Washington      M  High School or Below
# 3    XZ87318      Oregon      F               College
# 4    CF85061     Arizona      M                Master
# ..       ...         ...    ...                   ...
# 765  XD85577  California      M              Bachelor
# 766  TM65736      Oregon      M                Master
# 767  VJ51327  California      F  High School or Below
# 768  GS98873     Arizona      F              Bachelor
# 769  CW49887  California      F                Master
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                  697953.59      0.0                  94.0
# 1                  764586.18      0.0                 106.0
# 2                  536307.65  36357.0                  68.0
# 3                  538089.86  55350.0                  67.0
# ...

# %%
display(customer_data2)
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
display(customer_data3)
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
customer_data2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
customer_data2.columns= ["customer", "state", "gender", "education", "customer_lifetime_value", "income", "monthly_premium_auto", "number_open_complaints", "total_claim_amount", "policy_type", "vehicle_class"]
customer_data2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_open_complaints  total_claim_amount  \
# ...

# %%
customer_data3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
customer_data3.columns= ["customer", "state",  "customer_lifetime_value", "education", "gender","income", "monthly_premium_auto", "number_open_complaints", "policy_type", "total_claim_amount", "vehicle_class"]
customer_data3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_open_complaints  \
# ...

# %%
customer_data2.gender.unique()
# Out:
# array(['F', 'M', nan, 'female', 'Male'], dtype=object)

# %%
customer_data3.gender.unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
import seaborn as sns

# %%
sns.histplot(customer_data3['gender'], bins=10)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
gender_mapping = {
    'F': 'F',
    'female': 'F',
    'M': 'M',
    'Male': 'M',
}

# %%
customer_data2['gender'] = customer_data2['gender'].map(gender_mapping)
customer_data2.gender.value_counts()
# Out:
# gender
# F    529
# M    462
# Name: count, dtype: int64

# %%
sns.histplot(customer_data2['gender'], bins=10)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
customer_data2.describe(include="all")
# Out:
#        customer   state gender education customer_lifetime_value  \
# count       996     996    991       996                     992
# unique      996       6      2         6                     950
# top     GS98873  Oregon      F   College              552821.28%
# freq          1     303    529       311                       4
# mean        NaN     NaN    NaN       NaN                     NaN
# std         NaN     NaN    NaN       NaN                     NaN
# min         NaN     NaN    NaN       NaN                     NaN
# 25%         NaN     NaN    NaN       NaN                     NaN
# 50%         NaN     NaN    NaN       NaN                     NaN
# 75%         NaN     NaN    NaN       NaN                     NaN
# max         NaN     NaN    NaN       NaN                     NaN
#
#               income  monthly_premium_auto number_open_complaints  \
# count     996.000000            996.000000                    996
# ...

# %%
customer_data2 = customer_data2.dropna(subset="customer")
customer_data2 = customer_data2.dropna(subset="gender")
customer_data2 = customer_data2.dropna(subset="vehicle_class")

# %%
customer_data2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_open_complaints  total_claim_amount  \
# ...

# %%
customer_data3 = customer_data3.dropna(subset="customer")
customer_data3 = customer_data3.dropna(subset="gender")
customer_data3 = customer_data3.dropna(subset="vehicle_class")

# %%
customer_data3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_open_complaints  \
# ...

# %%
customer_data.nunique()
# Out:
# customer                   770
# state                        5
# gender                       2
# education                    5
# customer_lifetime_value    740
# income                     554
# monthly_premium_auto       128
# number_open_complaints       6
# policy_type                  3
# vehicle_class                3
# total_claim_amount         566
# open_complaints              6
# dtype: int64

# %%
customer_data2.nunique()
# Out:
# customer                   991
# state                        6
# gender                       2
# education                    6
# customer_lifetime_value    946
# income                     728
# monthly_premium_auto       126
# number_open_complaints       6
# total_claim_amount         666
# policy_type                  3
# vehicle_class                6
# dtype: int64

# %%
customer_data3.nunique()
# Out:
# customer                   7070
# state                         5
# customer_lifetime_value    6288
# education                     5
# gender                        2
# income                     4463
# monthly_premium_auto        194
# number_open_complaints        6
# policy_type                   3
# total_claim_amount         4025
# vehicle_class                 6
# dtype: int64

# %%
customer_data2.state.unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington', 'AZ'],
#       dtype=object)

# %%
state_mapping = {
    'Arizona': 'Arizona',
     "AZ": 'Arizona',
    'Oregon': 'Oregon',
    'California': 'California',
    'Nevada': 'Nevada',
    'Washington': 'Washington',
}

# %%
customer_data2['state'] = customer_data2['state'].map(state_mapping)
customer_data2.state.unique()
# Out:
# array(['Arizona', 'California', 'Oregon', 'Nevada', 'Washington'],
#       dtype=object)

# %%
customer_data3.state.unique()
# Out:
# array(['Washington', 'Arizona', 'Nevada', 'California', 'Oregon'],
#       dtype=object)

# %%
customer_data2.customer_lifetime_value
# Out:
# 0       323912.47%
# 1       462680.11%
# 2       899704.02%
# 3      2580706.30%
# 4       380812.21%
#           ...
# 991     847141.75%
# 992     543121.91%
# 993     568964.41%
# 994     368672.38%
# 995     399258.39%
# Name: customer_lifetime_value, Length: 991, dtype: object

# %%
customer_data2['customer_lifetime_value'] = customer_data2['customer_lifetime_value'].str.replace('%', '', regex=False)

# %%
customer_data2.education.unique()
# Out:
# array(['Bachelor', 'Master', 'College', 'Doctor', 'Bachelors',
#        'High School or Below'], dtype=object)

# %%
customer_data3.education.unique()
# Out:
# array(['High School or Below', 'Master', 'Bachelor', 'College', 'Doctor'],
#       dtype=object)

# %%
customer_data.education.unique()
# Out:
# array(['Bachelor', 'High School or Below', 'College', 'Master', 'Doctor'],
#       dtype=object)

# %%
education_mapping = {
    'Bachelor': 'Bachelor',
    'Bachelors': 'Bachelor',
    'College': 'College',
    'High School or Below': 'High School or Below',
    'Master': 'Master',
    'Doctor': 'Doctor',
}

# %%
customer_data2['education'] = customer_data2['education'].map(education_mapping)
customer_data2.education.value_counts()
# Out:
# education
# College                 310
# High School or Below    289
# Bachelor                257
# Master                   86
# Doctor                   49
# Name: count, dtype: int64

# %%
customer_data2.policy_type.unique()
# Out:
# array(['Personal Auto', 'Special Auto', 'Corporate Auto'], dtype=object)

# %%
customer_data.nunique()
# Out:
# customer                   770
# state                        5
# gender                       2
# education                    5
# customer_lifetime_value    740
# income                     554
# monthly_premium_auto       128
# number_open_complaints       6
# policy_type                  3
# vehicle_class                3
# total_claim_amount         566
# open_complaints              6
# dtype: int64

# %%
customer_data2.nunique()
# Out:
# customer                   991
# state                        5
# gender                       2
# education                    5
# customer_lifetime_value    946
# income                     728
# monthly_premium_auto       126
# number_open_complaints       6
# total_claim_amount         666
# policy_type                  3
# vehicle_class                6
# dtype: int64

# %%
customer_data3.nunique()
# Out:
# customer                   7070
# state                         5
# customer_lifetime_value    6288
# education                     5
# gender                        2
# income                     4463
# monthly_premium_auto        194
# number_open_complaints        6
# policy_type                   3
# total_claim_amount         4025
# vehicle_class                 6
# dtype: int64

# %%
vehicle_class_mapping = {
    'Four-Door Car': 'Four-Door Car',
    'Two-Door Car ': 'Two-Door Car ',
    'SUV': 'SUV',
    'Sports Car': 'Luxury',
    'Luxury SUV': 'Luxury',
    'Luxury Car': 'Luxury',
}

# %%
customer_data2['vehicle_class'] = customer_data2['vehicle_class'].map(vehicle_class_mapping)
customer_data3['vehicle_class'] = customer_data3['vehicle_class'].map(vehicle_class_mapping)

# %%
customer_data3.vehicle_class.value_counts()
# Out:
# vehicle_class
# Four-Door Car    3546
# SUV              1401
# Luxury            643
# Name: count, dtype: int64

# %%
customer_data2 = customer_data2.dropna(subset="customer")
customer_data2 = customer_data2.dropna(subset="gender")
customer_data2 = customer_data2.dropna(subset="vehicle_class")

customer_data3 = customer_data3.dropna(subset="customer")
customer_data3 = customer_data3.dropna(subset="gender")
customer_data3 = customer_data3.dropna(subset="vehicle_class")

# %%
customer_data2['customer_lifetime_value'] = pd.to_numeric(customer_data2['customer_lifetime_value'], errors='coerce')
customer_data2.customer_lifetime_value.value_counts()
# Out:
# customer_lifetime_value
# 552821.28    4
# 518162.09    3
# 538949.95    3
# 600521.48    3
# 871704.98    3
#             ..
# 253063.94    1
# 739671.97    1
# 383289.85    1
# 496140.59    1
# 399258.39    1
# Name: count, Length: 743, dtype: int64

# %%
customer_data3['customer_lifetime_value'] = pd.to_numeric(customer_data3['customer_lifetime_value'], errors='coerce')
customer_data3.customer_lifetime_value.value_counts()
# Out:
# customer_lifetime_value
# 3265.156348     6
# 22332.439460    6
# 26197.414980    6
# 2659.705650     6
# 13736.132500    6
#                ..
# 6745.248379     1
# 4491.909095     1
# 4315.670500     1
# 11281.524510    1
# 7524.442436     1
# Name: count, Length: 4972, dtype: int64

# %%
customer_data3.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              5590.000000   5590.000000           5590.000000
# mean               8385.344864  36939.424687             97.573166
# std                7287.797765  30238.931327             36.525825
# min                1904.000852      0.000000             61.000000
# 25%                4197.023446      0.000000             70.000000
# 50%                6049.412098  33399.500000             90.000000
# 75%                9318.213927  60956.000000            113.000000
# max               83325.381190  99961.000000            298.000000
#
#        number_open_complaints  total_claim_amount
# count             5590.000000         5590.000000
# mean                 0.383900          459.311738
# std                  0.915284          308.908944
# min                  0.000000            0.099007
# 25%                  0.000000          286.473641
# 50%                  0.000000          412.800000
# ...

# %%
customer_data2["number_open_complaints"].unique()
# Out:
# array(['1/0/00', '1/1/00', '1/3/00', '1/5/00', '1/2/00', '1/4/00'],
#       dtype=object)

# %%
customer_data2['open_complaints'] = customer_data2['number_open_complaints'].str.split('/').str[1]
customer_data2["open_complaints"].unique()
# Out:
# array(['0', '1', '3', '5', '2', '4'], dtype=object)

# %%
customer_data2['open_complaints'] = pd.to_numeric(customer_data2['open_complaints'])
customer_data2["open_complaints"]
# Out:
# 0      0
# 1      0
# 3      1
# 6      0
# 7      0
#       ..
# 988    0
# 990    0
# 991    0
# 992    0
# 995    0
# Name: open_complaints, Length: 781, dtype: int64

# %%
customer_data3['open_complaints'] = customer_data3['number_open_complaints']
customer_data3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# 5     VI78454     Arizona              2750.705045               College
# 6     FP59138      Oregon             13024.130120                Master
# ...       ...         ...                      ...                   ...
# 7064  YM19146  California              4100.398533               College
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
#
#      gender  income  monthly_premium_auto  number_open_complaints  \
# ...

# %%
customer_data3.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count              5590.000000   5590.000000           5590.000000
# mean               8385.344864  36939.424687             97.573166
# std                7287.797765  30238.931327             36.525825
# min                1904.000852      0.000000             61.000000
# 25%                4197.023446      0.000000             70.000000
# 50%                6049.412098  33399.500000             90.000000
# 75%                9318.213927  60956.000000            113.000000
# max               83325.381190  99961.000000            298.000000
#
#        number_open_complaints  total_claim_amount  open_complaints
# count             5590.000000         5590.000000      5590.000000
# mean                 0.383900          459.311738         0.383900
# std                  0.915284          308.908944         0.915284
# min                  0.000000            0.099007         0.000000
# ...

# %%
customer_data3.isnull().sum()
# Out:
# customer                   0
# state                      0
# customer_lifetime_value    0
# education                  0
# gender                     0
# income                     0
# monthly_premium_auto       0
# number_open_complaints     0
# policy_type                0
# total_claim_amount         0
# vehicle_class              0
# open_complaints            0
# dtype: int64

# %%
customer_data2.isnull().sum()
# Out:
# customer                   0
# state                      0
# gender                     0
# education                  0
# customer_lifetime_value    3
# income                     0
# monthly_premium_auto       0
# number_open_complaints     0
# total_claim_amount         0
# policy_type                0
# vehicle_class              0
# open_complaints            0
# dtype: int64

# %%
customer_data2['customer_lifetime_value'] = customer_data2['customer_lifetime_value'].fillna(customer_data2['customer_lifetime_value'].mean())
customer_data3['customer_lifetime_value'] = customer_data3['customer_lifetime_value'].fillna(customer_data3['customer_lifetime_value'].mean())

# %%
customer_data.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount',
#        'open_complaints'],
#       dtype='object')

# %%
new_order2 = ['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount',
       'open_complaints']

customer_data2= customer_data2[new_order2]
customer_data2.head()
# Out:
#   customer       state gender education  customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor                323912.47   16061
# 1  CW49887  California      F    Master                462680.11   79487
# 3  UH35128      Oregon      F   College               2580706.30   71210
# 6  UC84059  California      F    Master                689845.53   70950
# 7  HW62747      Oregon      M   College                229837.92       0
#
#    monthly_premium_auto number_open_complaints     policy_type  vehicle_class  \
# 0                    88                 1/0/00   Personal Auto  Four-Door Car
# 1                   114                 1/0/00    Special Auto            SUV
# 3                   214                 1/1/00   Personal Auto         Luxury
# 6                   171                 1/0/00   Personal Auto         Luxury
# 7                    63                 1/0/00  Corporate Auto  Four-Door Car
#
#    total_claim_amount  open_complaints
# ...

# %%
new_order3 = ['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount',
       'open_complaints']

customer_data3= customer_data3[new_order3]
customer_data3.head()
# Out:
#   customer       state gender             education  customer_lifetime_value  \
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
# 5  VI78454     Arizona      M               College              2750.705045
# 6  FP59138      Oregon      M                Master             13024.130120
#
#    income  monthly_premium_auto  number_open_complaints    policy_type  \
# 2   25820                    82                       0  Personal Auto
# 3       0                   121                       0  Personal Auto
# 4   30366                   101                       2  Personal Auto
# 5   51789                    70                       0  Personal Auto
# 6       0                   125                       0  Personal Auto
#
#    vehicle_class  total_claim_amount  open_complaints
# ...

# %%
# Merging the datasets
merged_df = customer_data.merge(customer_data2, on='customer', how='outer').merge(customer_data3, on='customer', how='outer')
merged_df
# Out:
#      customer     state_x gender_x education_x  customer_lifetime_value_x  \
# 0     AA10041         NaN      NaN         NaN                        NaN
# 1     AA16582         NaN      NaN         NaN                        NaN
# 2     AA30683         NaN      NaN         NaN                        NaN
# 3     AA34092         NaN      NaN         NaN                        NaN
# 4     AA35519         NaN      NaN         NaN                        NaN
# ...       ...         ...      ...         ...                        ...
# 7078  ZZ62245         NaN      NaN         NaN                        NaN
# 7079  ZZ68210         NaN      NaN         NaN                        NaN
# 7080  ZZ69693         NaN      NaN         NaN                        NaN
# 7081  ZZ91716  California        F    Bachelor                  325676.64
# 7082  ZZ97035  California        M     College                 2071494.04
#
#       income_x  monthly_premium_auto_x number_open_complaints_x  \
# ...

# %%
customer_data.to_csv('customer_data_merged.csv', index=False)

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
# Your code goes here
customer_analysis= pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")

# %%
display(customer_analysis)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %%
customer_analysis= customer_analysis.drop('unnamed:_0', axis=1)

# %%
display(customer_analysis)
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  ...  \
# ...

# %%
customer_analysis.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
customer_analysis.describe()
# Out:
#        customer_lifetime_value        income  monthly_premium_auto  \
# count             10910.000000  10910.000000          10910.000000
# mean               8018.241094  37536.284785             93.196059
# std                6885.081434  30359.195670             34.442532
# min                1898.007675      0.000000             61.000000
# 25%                4014.453113      0.000000             68.000000
# 50%                5771.147235  33813.500000             83.000000
# 75%                8992.779137  62250.750000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months_since_last_claim  months_since_policy_inception  \
# count             10910.000000                   10910.000000
# mean                 15.149071                      48.091934
# std                   9.783520                      27.940675
# min                   0.000000                       0.000000
# ...

# %%
customer_analysis.describe(include="object")
# Out:
#        customer       state response coverage education effective_to_date  \
# count     10910       10910    10910    10910     10910             10910
# unique     9134           5        2        3         5                59
# top     ID89933  California       No    Basic  Bachelor        2011-01-10
# freq          7        4183     9444     6660      3272               239
#
#        employmentstatus gender location_code marital_status    policy_type  \
# count             10910  10910         10910          10910          10910
# unique                5      2             3              3              3
# top            Employed      F      Suburban        Married  Personal Auto
# freq               6789   5573          6902           6319           8128
#
#              policy renew_offer_type sales_channel  vehicle_class  \
# count         10910            10910         10910          10910
# unique            9                4             4              6
# ...

# %%
sns.histplot(customer_analysis['state'], bins=10)
# Out:
# <Axes: xlabel='state', ylabel='Count'>

# %%
sns.histplot(customer_analysis['response'], bins=10)
# Out:
# <Axes: xlabel='response', ylabel='Count'>

# %%
sns.histplot(customer_analysis['coverage'], bins=10)
# Out:
# <Axes: xlabel='coverage', ylabel='Count'>

# %%
sns.histplot(customer_analysis['education'], bins=10)
# Out:
# <Axes: xlabel='education', ylabel='Count'>

# %%
# employmentstatus
sns.histplot(customer_analysis['employmentstatus'], bins=10)
# Out:
# <Axes: xlabel='employmentstatus', ylabel='Count'>

# %%
sns.histplot(customer_analysis['gender'], bins=10)
# Out:
# <Axes: xlabel='gender', ylabel='Count'>

# %%
sns.histplot(customer_analysis['location_code'], bins=10)
# Out:
# <Axes: xlabel='location_code', ylabel='Count'>

# %%
sns.histplot(customer_analysis['marital_status'], bins=10)
# Out:
# <Axes: xlabel='marital_status', ylabel='Count'>

# %%
sns.histplot(customer_analysis['policy_type'], bins=10)
# Out:
# <Axes: xlabel='policy_type', ylabel='Count'>

# %%
sns.histplot(customer_analysis['renew_offer_type'], bins=10)
# Out:
# <Axes: xlabel='renew_offer_type', ylabel='Count'>

# %%
sns.histplot(customer_analysis['sales_channel'], bins=10)
# Out:
# <Axes: xlabel='sales_channel', ylabel='Count'>

# %%
sns.histplot(customer_analysis['vehicle_class'], bins=10)
# Out:
# <Axes: xlabel='vehicle_class', ylabel='Count'>

# %%
sns.histplot(customer_analysis['vehicle_size'], bins=10)
# Out:
# <Axes: xlabel='vehicle_size', ylabel='Count'>

# %%
customer_analysis.effective_to_date.unique()
# Out:
# array(['2011-02-18', '2011-01-18', '2011-02-10', '2011-01-11',
#        '2011-01-17', '2011-02-14', '2011-02-24', '2011-01-19',
#        '2011-01-04', '2011-01-02', '2011-02-07', '2011-01-31',
#        '2011-01-26', '2011-02-28', '2011-01-16', '2011-02-26',
#        '2011-02-23', '2011-01-15', '2011-02-02', '2011-02-15',
#        '2011-01-24', '2011-02-21', '2011-02-22', '2011-01-07',
#        '2011-01-28', '2011-02-08', '2011-02-12', '2011-02-20',
#        '2011-01-05', '2011-02-19', '2011-01-03', '2011-02-03',
#        '2011-01-22', '2011-01-23', '2011-02-05', '2011-02-13',
#        '2011-01-25', '2011-02-16', '2011-02-01', '2011-01-27',
#        '2011-01-12', '2011-01-20', '2011-02-06', '2011-02-11',
#        '2011-01-21', '2011-01-29', '2011-01-09', '2011-02-09',
#        '2011-02-27', '2011-01-01', '2011-02-17', '2011-02-25',
#        '2011-01-13', '2011-01-06', '2011-02-04', '2011-01-14',
#        '2011-01-10', '2011-01-08', '2011-01-30'], dtype=object)

# %%
customer_analysis.policy.unique()
# Out:
# array(['Corporate L3', 'Personal L3', 'Personal L2', 'Corporate L2',
#        'Personal L1', 'Special L1', 'Corporate L1', 'Special L3',
#        'Special L2'], dtype=object)

# %%
customer_analysis.vehicle_class.unique()
# Out:
# array(['Four-Door Car', 'SUV', 'Two-Door Car', 'Sports Car', 'Luxury Car',
#        'Luxury SUV'], dtype=object)

# %%
customer_analysis.vehicle_type.unique()
# Out:
# array(['A'], dtype=object)

# %%
customer_analysis.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
summary_table = customer_analysis.pivot_table(values='customer_lifetime_value', 
                                index='sales_channel', 
                                aggfunc='sum').reset_index()

summary_table['customer_lifetime_value'] = summary_table['customer_lifetime_value'].round(2)
print(summary_table)
# Out:
#   sales_channel  customer_lifetime_value
# 0         Agent              33057887.85
# 1        Branch              24359201.21
# 2   Call Center              17364288.37
# 3           Web              12697632.90

# %%
summary_table2 = customer_analysis.pivot_table(values='monthly_premium_auto', 
                                index='sales_channel', 
                                aggfunc='sum').reset_index()

summary_table2['monthly_premium_auto'] = summary_table2['monthly_premium_auto'].round(2)
print(summary_table2)
# Out:
#   sales_channel  monthly_premium_auto
# 0         Agent                386335
# 1        Branch                280953
# 2   Call Center                197970
# 3           Web                151511

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
customer_analysis.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size', 'vehicle_type', 'month'],
#       dtype='object')

# %%
pivot_table = customer_analysis.pivot_table(values='customer_lifetime_value', 
                              index='gender', 
                              columns='education', 
                              aggfunc='mean').round(2)

print(pivot_table)
# Out:
# education  Bachelor  College   Doctor  High School or Below   Master
# gender
# F           7874.27  7748.82  7328.51               8675.22  8157.05
# M           7703.60  8052.46  7415.33               8149.69  8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
